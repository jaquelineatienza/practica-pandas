# %%
#1

import pandas as pd
import matplotlib as plt

# %%
archivo = pd.read_csv('comercio-interno.csv', encoding='latin1')
df = pd.DataFrame(archivo)
df.head(20)
# Out:
#     sector_id     sector_nombre  variable_id  \
# 0          31  Comercio interno          762
# 1          31  Comercio interno          762
# 2          31  Comercio interno          762
# 3          31  Comercio interno          762
# 4          31  Comercio interno          762
# 5          31  Comercio interno          762
# 6          31  Comercio interno          762
# 7          31  Comercio interno          762
# 8          31  Comercio interno          762
# 9          31  Comercio interno          762
# 10         31  Comercio interno          762
# 11         31  Comercio interno          762
# 12         31  Comercio interno          762
# 13         31  Comercio interno          762
# 14         31  Comercio interno          762
# 15         31  Comercio interno          762
# 16         31  Comercio interno          762
# 17         31  Comercio interno          762
# 18         31  Comercio interno          762
# 19         31  Comercio interno          762
#
# ...

# %%
print(df.dtypes)
print(df.isnull().sum())
# Out:
# sector_id                      int64
# sector_nombre                 object
# variable_id                    int64
# actividad_producto_nombre     object
# indicador                     object
# unidad_de_medida              object
# fuente                        object
# frecuencia_nombre             object
# cobertura_nombre              object
# alcance_tipo                  object
# alcance_id                     int64
# alcance_nombre                object
# indice_tiempo                 object
# valor                        float64
# dtype: object
# sector_id                       0
# sector_nombre                   0
# variable_id                     0
# actividad_producto_nombre       0
# indicador                       0
# unidad_de_medida                0
# fuente                          0
# frecuencia_nombre               0
# cobertura_nombre                0
# alcance_tipo                    0
# alcance_id                      0
# alcance_nombre                  0
# ...

# %%
print(df['valor'])
# Out:
# 0        3.407774e+05
# 1        3.282887e+05
# 2        3.533352e+05
# 3        3.596945e+05
# 4        3.365680e+05
#              ...
# 35289    3.254334e+06
# 35290    3.421900e+06
# 35291    3.622858e+06
# 35292    3.164424e+06
# 35293    3.056590e+06
# Name: valor, Length: 35294, dtype: float64
